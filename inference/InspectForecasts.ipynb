# %%
import xarray as xr

# %%
fcs=xr.open_dataset("GraphTransformer_forecast_20240401T0600.nc")

# %%
fcs["wind_power"].values
# Out:
# array([[0.12584119, 0.15312444, 0.24897686, ..., 0.        , 0.        ,
#         0.        ],
#        [0.46128106, 0.54680175, 0.72585016, ..., 0.77177733, 0.7084066 ,
#         0.67512816],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        ...,
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan]], dtype=float32)
